# %% [markdown]
# <a href="https://colab.research.google.com/github/mskhan1103/Object-Detection/blob/main/Hard_Hat_Workers(using%20YOLO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 46.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 72.7 MB/s eta 0:00:00

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="UVynpeaBPWtSeiT7QTXx")  # public demo key
project = rf.workspace("salmanworkspace").project("hard-hat-workers-cxhtv")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Hard-Hat-Workers-1 in yolov8:: 100%|██████████| 14082/14082 [00:01<00:00, 8566.37it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !ls /content
# !ls /content/Hard-Hat-Workers-1/train/images | head
# Out:
# Hard-Hat-Workers-1  sample_data
# 000001_jpg.rf.f0f3d5a41e4ab3a7c1424d2eefbaf72a.jpg
# 000002_jpg.rf.fb3af27a4baf1f8a23560a32ea6304ae.jpg
# 000003_jpg.rf.aa3808640788e606f9a21135d1e4f55b.jpg
# 000004_jpg.rf.123cc8a3ec9cd4118851983b5252e0b9.jpg
# 000005_jpg.rf.f9d6909b0d103e884e01077363462c04.jpg
# 000006_jpg.rf.2b14ed27452bb7d1e60e454928ffc228.jpg
# 000007_jpg.rf.4cd2bb558f4ce962253a2b655352961a.jpg
# 000008_jpg.rf.03a18df796b7ff4c7516fb0d68fa1fab.jpg
# 000009_jpg.rf.098bdce20b667ffdc5c2adecd0d27c73.jpg
# 000010_jpg.rf.89c88e7f5d5fa05ddcd3c32475d556a6.jpg

# %%
from ultralytics import YOLO

# Load YOLOv8 Nano model (small and fast)
model = YOLO("yolov8n.pt")

# Train on the dataset
model.train(
    data="/content/Hard-Hat-Workers-1/data.yaml",
    epochs=30,
    imgsz=416,
    batch=8,
    name="helmet_yolov8n"
)
# Out:
# ...
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2220317829.py in <cell line: 0>()
#       2
#       3 # Load trained model
# ----> 4 model = YOLO("/content/runs/detect/helmet_yolov8n/best.pt")
#       5
#       6 # Evaluate on test dataset
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      81         else:
#      82             # Continue with default YOLO initialization
# ---> 83             super().__init__(model=model, task=task, verbose=verbose)
#      84             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      85                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
# ...
